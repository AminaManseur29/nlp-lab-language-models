# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')

# Utilisation de Counter pour compter la fréquence des caractères
counter = collections.Counter(text)
# Nombre de caractères uniques
chars = counter.keys()
print(f'{len(chars)} different characters')

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# 101 different characters
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
# Définition du point de séparation (90% des données pour l'entraînement)
split_idx = int(0.9 * len(data))

# Découpage en données d'entraînement et de validation
train_data = data[:split_idx]
val_data = data[split_idx:]

print(f'Taille des données d\'entraînement : {len(train_data)}')
print(f'Taille des données de validation : {len(val_data)}')
###
# Out:
# Taille des données d'entraînement : 256699
# Taille des données de validation : 28523

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([19163])
# context is >s< target is > <
# context is >s < target is >p<
# context is >s p< target is >o<
# context is >s po< target is >r<
# context is >s por< target is >t<
# context is >s port< target is >e<
# context is >s porte< target is >s<
# context is >s portes< target is > <

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(0, len(data) - block_size, (batch_size,))
    
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    
    # y is the character after each starting position
    y = torch.stack([data[i+1:i+block_size+1] for i in starting_points])

    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn
import torch.nn.functional as F

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        self.embedding = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        logits = self.embedding(idx)
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = 101
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 4.960083961486816

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))

# Créer le prompt avec l'entier correspondant au caractère '\n'
newline_token = torch.tensor([[encode('\n')]], dtype=torch.long).to(device)  # (1, 1)

# Générer une séquence de 100 caractères
generated_sequence = m.generate(newline_token, max_new_tokens=100)

# Décoder pour obtenir la phrase générée
generated_text = decode(generated_sequence.tolist()[0])

print(generated_text)
# Out:
# [3]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 7
#       4 newline_token = torch.tensor([[encode('\n')]], dtype=torch.long).to(device)  # (1, 1)
#       6 # Générer une séquence de 100 caractères
# ----> 7 generated_sequence = m.generate(newline_token, max_new_tokens=100)
#       9 # Décoder pour obtenir la phrase générée
#      10 generated_text = decode(generated_sequence.tolist()[0])
#
# Cell In[13], line 47, in BigramLanguageModel.generate(self, idx, max_new_tokens)
#      45 probs = nn.functional.softmax(logits, dim=-1) # (B, C)
#      46 # sample from the distribution
# ---> 47 idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
#      48 # append sampled index to the running sequence
#      49 idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
#
# RuntimeError: prob_dist must be 1 or 2 dim

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.9276, val loss 4.9822
# step 10: train loss 4.9025, val loss 4.8640
# step 20: train loss 4.9638, val loss 4.9267
# step 30: train loss 4.9989, val loss 4.8882
# step 40: train loss 4.8595, val loss 4.8201
# step 50: train loss 4.9593, val loss 4.8580
# step 60: train loss 4.8742, val loss 4.8599
# step 70: train loss 4.9277, val loss 4.8835
# step 80: train loss 4.8397, val loss 4.8584
# step 90: train loss 4.9538, val loss 4.7691
# step 100: train loss 4.9105, val loss 4.8019
# step 110: train loss 4.9586, val loss 4.8354
# step 120: train loss 4.9133, val loss 4.8120
# step 130: train loss 4.8932, val loss 4.6796
# step 140: train loss 4.9471, val loss 4.8261
# step 150: train loss 4.8711, val loss 4.7502
# step 160: train loss 4.8966, val loss 4.7441
# step 170: train loss 4.8574, val loss 4.6944
# step 180: train loss 4.8743, val loss 4.7258
# step 190: train loss 4.8133, val loss 4.7087
# step 200: train loss 4.7748, val loss 4.5928
# step 210: train loss 4.8431, val loss 4.6619
# step 220: train loss 4.8046, val loss 4.6183
# step 230: train loss 4.7510, val loss 4.7633
# step 240: train loss 4.8109, val loss 4.6827
# step 250: train loss 4.7864, val loss 4.5863
# step 260: train loss 4.7395, val loss 4.6329
# step 270: train loss 4.7633, val loss 4.6937
# step 280: train loss 4.7875, val loss 4.7070
# step 290: train loss 4.7996, val loss 4.6815
# step 300: train loss 4.7807, val loss 4.6850
# step 310: train loss 4.7628, val loss 4.5962
# step 320: train loss 4.6995, val loss 4.6109
# step 330: train loss 4.7755, val loss 4.5991
# step 340: train loss 4.6906, val loss 4.6804
# step 350: train loss 4.6368, val loss 4.4967
# step 360: train loss 4.6893, val loss 4.5592
# step 370: train loss 4.6064, val loss 4.5926
# step 380: train loss 4.6586, val loss 4.6061
# step 390: train loss 4.6231, val loss 4.5362
# step 400: train loss 4.6325, val loss 4.5728
# step 410: train loss 4.5906, val loss 4.4591
# step 420: train loss 4.6070, val loss 4.5174
# step 430: train loss 4.5758, val loss 4.5944
# step 440: train loss 4.6070, val loss 4.5696
# step 450: train loss 4.5639, val loss 4.4939
# step 460: train loss 4.5522, val loss 4.5968
# step 470: train loss 4.5716, val loss 4.5577
# step 480: train loss 4.5146, val loss 4.5544
# step 490: train loss 4.5649, val loss 4.3395
# step 500: train loss 4.5831, val loss 4.4759
# step 510: train loss 4.5924, val loss 4.4664
# step 520: train loss 4.5213, val loss 4.4175
# step 530: train loss 4.6091, val loss 4.3833
# step 540: train loss 4.5354, val loss 4.4291
# step 550: train loss 4.5653, val loss 4.4439
# step 560: train loss 4.5605, val loss 4.5294
# step 570: train loss 4.5522, val loss 4.5424
# step 580: train loss 4.5325, val loss 4.4813
# step 590: train loss 4.5046, val loss 4.4096
# step 600: train loss 4.5180, val loss 4.4453
# step 610: train loss 4.4895, val loss 4.3718
# step 620: train loss 4.4327, val loss 4.3280
# step 630: train loss 4.4523, val loss 4.3212
# step 640: train loss 4.4611, val loss 4.2910
# step 650: train loss 4.5132, val loss 4.3716
# step 660: train loss 4.4279, val loss 4.2709
# step 670: train loss 4.5037, val loss 4.3473
# step 680: train loss 4.5249, val loss 4.3302
# step 690: train loss 4.4684, val loss 4.3987
# step 700: train loss 4.4482, val loss 4.2772
# step 710: train loss 4.3905, val loss 4.3626
# step 720: train loss 4.4147, val loss 4.2979
# step 730: train loss 4.3738, val loss 4.2687
# step 740: train loss 4.4527, val loss 4.3415
# step 750: train loss 4.3600, val loss 4.2745
# step 760: train loss 4.3934, val loss 4.2434
# step 770: train loss 4.3748, val loss 4.3666
# step 780: train loss 4.4552, val loss 4.3344
# step 790: train loss 4.3782, val loss 4.2439
# step 800: train loss 4.2980, val loss 4.3375
# step 810: train loss 4.3037, val loss 4.2502
# step 820: train loss 4.3524, val loss 4.2211
# step 830: train loss 4.3784, val loss 4.2605
# step 840: train loss 4.3024, val loss 4.2986
# step 850: train loss 4.2259, val loss 4.3147
# step 860: train loss 4.2907, val loss 4.2351
# step 870: train loss 4.2680, val loss 4.2950
# step 880: train loss 4.3484, val loss 4.2188
# step 890: train loss 4.3143, val loss 4.2411
# step 900: train loss 4.3226, val loss 4.2697
# step 910: train loss 4.2068, val loss 4.1612
# step 920: train loss 4.2451, val loss 4.1560
# step 930: train loss 4.2477, val loss 4.1706
# step 940: train loss 4.3203, val loss 4.2066
# step 950: train loss 4.2150, val loss 4.2185
# step 960: train loss 4.2031, val loss 4.2381
# step 970: train loss 4.2648, val loss 4.1769
# step 980: train loss 4.1795, val loss 4.1904
# step 990: train loss 4.2232, val loss 4.1017
# step 1000: train loss 4.2096, val loss 4.1362
# step 1010: train loss 4.1949, val loss 4.2238
# step 1020: train loss 4.1708, val loss 4.1436
# step 1030: train loss 4.2187, val loss 4.0676
# step 1040: train loss 4.1619, val loss 4.1142
# step 1050: train loss 4.1570, val loss 4.1532
# step 1060: train loss 4.1420, val loss 4.0730
# step 1070: train loss 4.1018, val loss 4.0772
# step 1080: train loss 4.1414, val loss 4.0705
# step 1090: train loss 4.1114, val loss 4.1114
# step 1100: train loss 4.1352, val loss 4.1944
# step 1110: train loss 4.1341, val loss 4.1369
# step 1120: train loss 4.1800, val loss 4.1486
# step 1130: train loss 4.0758, val loss 4.0419
# step 1140: train loss 4.1987, val loss 4.0743
# step 1150: train loss 4.1012, val loss 4.0940
# step 1160: train loss 4.1847, val loss 4.1442
# step 1170: train loss 4.1763, val loss 4.0264
# step 1180: train loss 4.0666, val loss 4.0000
# step 1190: train loss 4.0657, val loss 4.1191
# step 1200: train loss 4.0316, val loss 4.0844
# step 1210: train loss 4.0972, val loss 3.9793
# step 1220: train loss 4.0609, val loss 3.9863
# step 1230: train loss 4.0639, val loss 3.9669
# step 1240: train loss 4.0778, val loss 3.9685
# step 1250: train loss 4.0518, val loss 4.0445
# step 1260: train loss 4.0482, val loss 3.9523
# step 1270: train loss 4.0210, val loss 3.9881
# step 1280: train loss 3.9948, val loss 4.0652
# step 1290: train loss 4.0763, val loss 4.0204
# step 1300: train loss 3.9804, val loss 4.0297
# step 1310: train loss 4.0167, val loss 4.0225
# step 1320: train loss 3.9900, val loss 3.9758
# step 1330: train loss 3.9248, val loss 3.9494
# step 1340: train loss 4.0146, val loss 3.8775
# step 1350: train loss 3.9802, val loss 3.9425
# step 1360: train loss 3.9941, val loss 3.9675
# step 1370: train loss 3.9096, val loss 3.9866
# step 1380: train loss 3.9185, val loss 3.9287
# step 1390: train loss 3.9812, val loss 3.9216
# step 1400: train loss 3.9647, val loss 3.8639
# step 1410: train loss 3.8657, val loss 3.9700
# step 1420: train loss 4.0101, val loss 3.9894
# step 1430: train loss 3.9140, val loss 3.8878
# step 1440: train loss 3.9225, val loss 3.9710
# step 1450: train loss 3.9021, val loss 3.8275
# step 1460: train loss 3.9398, val loss 4.0207
# step 1470: train loss 3.9467, val loss 3.9505
# step 1480: train loss 3.9105, val loss 3.7719
# step 1490: train loss 3.9059, val loss 3.9216
# step 1500: train loss 3.8771, val loss 3.8469
# step 1510: train loss 3.8647, val loss 3.9509
# step 1520: train loss 3.9111, val loss 3.8390
# step 1530: train loss 3.8908, val loss 3.8646
# step 1540: train loss 3.8392, val loss 3.8666
# step 1550: train loss 3.9132, val loss 3.8082
# step 1560: train loss 3.9013, val loss 3.7837
# step 1570: train loss 3.8221, val loss 3.8712
# step 1580: train loss 3.8830, val loss 3.8177
# step 1590: train loss 3.8061, val loss 3.8267
# step 1600: train loss 3.8690, val loss 3.8279
# step 1610: train loss 3.8152, val loss 3.8726
# step 1620: train loss 3.8306, val loss 3.7921
# step 1630: train loss 3.8223, val loss 3.8260
# step 1640: train loss 3.7991, val loss 3.6807
# step 1650: train loss 3.8454, val loss 3.8659
# step 1660: train loss 3.8063, val loss 3.8124
# step 1670: train loss 3.8380, val loss 3.7495
# step 1680: train loss 3.7741, val loss 3.7851
# step 1690: train loss 3.8749, val loss 3.8683
# step 1700: train loss 3.7630, val loss 3.7234
# step 1710: train loss 3.8280, val loss 3.7558
# step 1720: train loss 3.8109, val loss 3.8650
# step 1730: train loss 3.8130, val loss 3.7634
# step 1740: train loss 3.7766, val loss 3.7054
# step 1750: train loss 3.8040, val loss 3.8403
# step 1760: train loss 3.8083, val loss 3.6930
# step 1770: train loss 3.7113, val loss 3.7558
# step 1780: train loss 3.6702, val loss 3.6779
# step 1790: train loss 3.7539, val loss 3.7170
# step 1800: train loss 3.7250, val loss 3.7032
# step 1810: train loss 3.6897, val loss 3.7109
# step 1820: train loss 3.7889, val loss 3.6581
# step 1830: train loss 3.6755, val loss 3.7608
# step 1840: train loss 3.7290, val loss 3.7154
# step 1850: train loss 3.7313, val loss 3.7185
# step 1860: train loss 3.6573, val loss 3.7064
# step 1870: train loss 3.7294, val loss 3.6943
# step 1880: train loss 3.7701, val loss 3.6120
# step 1890: train loss 3.7423, val loss 3.7596
# step 1900: train loss 3.6774, val loss 3.6569
# step 1910: train loss 3.7511, val loss 3.7925
# step 1920: train loss 3.7146, val loss 3.7184
# step 1930: train loss 3.7150, val loss 3.6815
# step 1940: train loss 3.5963, val loss 3.6403
# step 1950: train loss 3.6447, val loss 3.6767
# step 1960: train loss 3.6254, val loss 3.6758
# step 1970: train loss 3.6504, val loss 3.7328
# step 1980: train loss 3.6064, val loss 3.6007
# step 1990: train loss 3.6320, val loss 3.5847
# step 2000: train loss 3.6442, val loss 3.6071
# step 2010: train loss 3.6692, val loss 3.6616
# step 2020: train loss 3.6277, val loss 3.6797
# step 2030: train loss 3.7104, val loss 3.5934
# step 2040: train loss 3.6265, val loss 3.6426
# step 2050: train loss 3.6967, val loss 3.6009
# step 2060: train loss 3.5503, val loss 3.5297
# step 2070: train loss 3.6764, val loss 3.6664
# step 2080: train loss 3.6017, val loss 3.6085
# step 2090: train loss 3.6188, val loss 3.5203
# step 2100: train loss 3.6223, val loss 3.6594
# step 2110: train loss 3.5375, val loss 3.5975
# step 2120: train loss 3.4798, val loss 3.5620
# step 2130: train loss 3.5923, val loss 3.5673
# step 2140: train loss 3.5720, val loss 3.6097
# step 2150: train loss 3.5789, val loss 3.6394
# step 2160: train loss 3.5693, val loss 3.6389
# step 2170: train loss 3.5966, val loss 3.5727
# step 2180: train loss 3.5370, val loss 3.6471
# step 2190: train loss 3.4823, val loss 3.5077
# step 2200: train loss 3.5590, val loss 3.5692
# step 2210: train loss 3.6046, val loss 3.5260
# step 2220: train loss 3.5188, val loss 3.5989
# step 2230: train loss 3.5641, val loss 3.5287
# step 2240: train loss 3.5740, val loss 3.4750
# step 2250: train loss 3.5751, val loss 3.5928
# step 2260: train loss 3.5599, val loss 3.5117
# step 2270: train loss 3.6200, val loss 3.4730
# step 2280: train loss 3.5284, val loss 3.4730
# step 2290: train loss 3.5259, val loss 3.4825
# step 2300: train loss 3.5648, val loss 3.5354
# step 2310: train loss 3.4876, val loss 3.4908
# step 2320: train loss 3.5218, val loss 3.6713
# step 2330: train loss 3.4863, val loss 3.4205
# step 2340: train loss 3.5289, val loss 3.4644
# step 2350: train loss 3.5444, val loss 3.5619
# step 2360: train loss 3.3968, val loss 3.4626
# step 2370: train loss 3.4520, val loss 3.4620
# step 2380: train loss 3.4888, val loss 3.4336
# step 2390: train loss 3.4682, val loss 3.3660
# step 2400: train loss 3.4624, val loss 3.4011
# step 2410: train loss 3.4784, val loss 3.4375
# step 2420: train loss 3.5114, val loss 3.4657
# step 2430: train loss 3.5314, val loss 3.4176
# step 2440: train loss 3.5050, val loss 3.4857
# step 2450: train loss 3.3945, val loss 3.3916
# step 2460: train loss 3.4455, val loss 3.4067
# step 2470: train loss 3.4735, val loss 3.4158
# step 2480: train loss 3.4179, val loss 3.3980
# step 2490: train loss 3.4674, val loss 3.5473
# step 2500: train loss 3.4908, val loss 3.5022
# step 2510: train loss 3.4673, val loss 3.4558
# step 2520: train loss 3.4164, val loss 3.4995
# step 2530: train loss 3.4423, val loss 3.4381
# step 2540: train loss 3.3969, val loss 3.4698
# step 2550: train loss 3.4732, val loss 3.4111
# step 2560: train loss 3.4069, val loss 3.3233
# step 2570: train loss 3.4068, val loss 3.3877
# step 2580: train loss 3.4181, val loss 3.4756
# step 2590: train loss 3.4180, val loss 3.3468
# step 2600: train loss 3.4480, val loss 3.5264
# step 2610: train loss 3.4004, val loss 3.4085
# step 2620: train loss 3.3820, val loss 3.2644
# step 2630: train loss 3.3427, val loss 3.4106
# step 2640: train loss 3.4391, val loss 3.4665
# step 2650: train loss 3.3544, val loss 3.3943
# step 2660: train loss 3.3662, val loss 3.4086
# step 2670: train loss 3.3476, val loss 3.3829
# step 2680: train loss 3.3642, val loss 3.2947
# step 2690: train loss 3.3769, val loss 3.3657
# step 2700: train loss 3.3626, val loss 3.3322
# step 2710: train loss 3.4279, val loss 3.3212
# step 2720: train loss 3.4268, val loss 3.4562
# step 2730: train loss 3.3227, val loss 3.2615
# step 2740: train loss 3.3621, val loss 3.3033
# step 2750: train loss 3.3774, val loss 3.3182
# step 2760: train loss 3.3376, val loss 3.3123
# step 2770: train loss 3.4004, val loss 3.3600
# step 2780: train loss 3.3041, val loss 3.3465
# step 2790: train loss 3.3579, val loss 3.3803
# step 2800: train loss 3.3747, val loss 3.3432
# step 2810: train loss 3.2533, val loss 3.4357
# step 2820: train loss 3.3094, val loss 3.3127
# step 2830: train loss 3.3318, val loss 3.3057
# step 2840: train loss 3.2539, val loss 3.4016
# step 2850: train loss 3.3776, val loss 3.2791
# step 2860: train loss 3.2781, val loss 3.3078
# step 2870: train loss 3.3634, val loss 3.2913
# step 2880: train loss 3.2516, val loss 3.2075
# step 2890: train loss 3.3123, val loss 3.4340
# step 2900: train loss 3.3588, val loss 3.2867
# step 2910: train loss 3.2969, val loss 3.2490
# step 2920: train loss 3.3252, val loss 3.2520
# step 2930: train loss 3.2941, val loss 3.3127
# step 2940: train loss 3.2175, val loss 3.3321
# step 2950: train loss 3.2212, val loss 3.3164
# step 2960: train loss 3.2824, val loss 3.2407
# step 2970: train loss 3.2802, val loss 3.2855
# step 2980: train loss 3.2431, val loss 3.2536
# step 2990: train loss 3.2656, val loss 3.3333
# step 3000: train loss 3.2655, val loss 3.1710
# step 3010: train loss 3.2743, val loss 3.2001
# step 3020: train loss 3.1724, val loss 3.3804
# step 3030: train loss 3.2300, val loss 3.2997
# step 3040: train loss 3.2028, val loss 3.1691
# step 3050: train loss 3.2741, val loss 3.3164
# step 3060: train loss 3.3272, val loss 3.2415
# step 3070: train loss 3.1984, val loss 3.2354
# step 3080: train loss 3.1883, val loss 3.2884
# step 3090: train loss 3.2690, val loss 3.2590
# step 3100: train loss 3.2299, val loss 3.2063
# step 3110: train loss 3.2282, val loss 3.2634
# step 3120: train loss 3.1928, val loss 3.2350
# step 3130: train loss 3.2939, val loss 3.2639
# step 3140: train loss 3.1965, val loss 3.2854
# step 3150: train loss 3.1869, val loss 3.1476
# step 3160: train loss 3.1092, val loss 3.2395
# step 3170: train loss 3.2381, val loss 3.2219
# step 3180: train loss 3.3089, val loss 3.2252
# step 3190: train loss 3.3395, val loss 3.1893
# step 3200: train loss 3.2317, val loss 3.3030
# step 3210: train loss 3.2206, val loss 3.2376
# step 3220: train loss 3.2414, val loss 3.0733
# step 3230: train loss 3.1562, val loss 3.2101
# step 3240: train loss 3.3270, val loss 3.2608
# step 3250: train loss 3.1872, val loss 3.3069
# step 3260: train loss 3.2509, val loss 3.1745
# step 3270: train loss 3.1672, val loss 3.1427
# step 3280: train loss 3.1728, val loss 3.2159
# step 3290: train loss 3.1800, val loss 3.0637
# step 3300: train loss 3.1977, val loss 3.2838
# step 3310: train loss 3.2168, val loss 3.0962
# step 3320: train loss 3.2358, val loss 3.1097
# step 3330: train loss 3.1417, val loss 3.1198
# step 3340: train loss 3.1600, val loss 3.1263
# step 3350: train loss 3.1685, val loss 3.2158
# step 3360: train loss 3.1313, val loss 3.1706
# step 3370: train loss 3.2221, val loss 3.1858
# step 3380: train loss 3.0875, val loss 3.1417
# step 3390: train loss 3.1818, val loss 3.2439
# step 3400: train loss 3.1795, val loss 3.1679
# step 3410: train loss 3.0580, val loss 3.1815
# step 3420: train loss 3.1025, val loss 3.1417
# step 3430: train loss 3.0326, val loss 3.1697
# step 3440: train loss 3.1463, val loss 3.1764
# step 3450: train loss 3.0972, val loss 3.0815
# step 3460: train loss 3.1103, val loss 3.1471
# step 3470: train loss 3.1688, val loss 3.1502
# step 3480: train loss 3.1241, val loss 3.0668
# step 3490: train loss 3.1407, val loss 3.1142
# step 3500: train loss 3.1137, val loss 3.0752
# step 3510: train loss 3.1380, val loss 3.0866
# step 3520: train loss 3.1293, val loss 3.1282
# step 3530: train loss 3.0584, val loss 3.1551
# step 3540: train loss 3.1512, val loss 3.1011
# step 3550: train loss 3.1110, val loss 3.1794
# step 3560: train loss 3.1415, val loss 3.1760
# step 3570: train loss 3.0996, val loss 3.1650
# step 3580: train loss 3.1243, val loss 3.1281
# step 3590: train loss 3.1240, val loss 3.0574
# step 3600: train loss 3.0807, val loss 3.1719
# step 3610: train loss 3.0857, val loss 3.0890
# step 3620: train loss 3.0905, val loss 3.1396
# step 3630: train loss 3.1360, val loss 3.1595
# step 3640: train loss 3.1613, val loss 3.1204
# step 3650: train loss 3.1510, val loss 2.9804
# step 3660: train loss 3.1317, val loss 3.1298
# step 3670: train loss 3.0847, val loss 3.0973
# step 3680: train loss 3.0987, val loss 3.1764
# step 3690: train loss 3.1101, val loss 2.9957
# step 3700: train loss 3.1433, val loss 3.1432
# step 3710: train loss 3.1381, val loss 3.0815
# step 3720: train loss 3.0867, val loss 3.0246
# step 3730: train loss 3.0214, val loss 3.1340
# step 3740: train loss 3.0582, val loss 3.0799
# step 3750: train loss 3.0340, val loss 3.1011
# step 3760: train loss 3.0144, val loss 3.0479
# step 3770: train loss 3.0616, val loss 3.0477
# step 3780: train loss 2.9687, val loss 2.9632
# step 3790: train loss 3.0062, val loss 3.0654
# step 3800: train loss 3.0648, val loss 3.0300
# step 3810: train loss 3.0441, val loss 3.0871
# step 3820: train loss 3.0144, val loss 3.0274
# step 3830: train loss 3.0318, val loss 3.1065
# step 3840: train loss 3.0078, val loss 3.0313
# step 3850: train loss 2.9825, val loss 3.0226
# step 3860: train loss 2.9423, val loss 3.0714
# step 3870: train loss 3.0061, val loss 3.0370
# step 3880: train loss 2.9876, val loss 3.1320
# step 3890: train loss 2.9684, val loss 2.9774
# step 3900: train loss 3.0099, val loss 3.1214
# step 3910: train loss 3.0288, val loss 3.0095
# step 3920: train loss 2.9212, val loss 3.1031
# step 3930: train loss 3.0255, val loss 3.1104
# step 3940: train loss 2.9534, val loss 2.9847
# step 3950: train loss 3.0258, val loss 3.0262
# step 3960: train loss 3.0652, val loss 3.0327
# step 3970: train loss 3.0076, val loss 3.0395
# step 3980: train loss 3.0551, val loss 3.0262
# step 3990: train loss 2.9730, val loss 3.0866
# step 4000: train loss 3.0176, val loss 3.0635
# step 4010: train loss 2.9778, val loss 2.9505
# step 4020: train loss 3.0417, val loss 3.0956
# step 4030: train loss 2.9651, val loss 2.9077
# step 4040: train loss 3.0197, val loss 3.0515
# step 4050: train loss 2.9382, val loss 3.0354
# step 4060: train loss 3.0803, val loss 2.9953
# step 4070: train loss 3.0020, val loss 2.9720
# step 4080: train loss 3.0662, val loss 2.8511
# step 4090: train loss 3.0111, val loss 3.0458
# step 4100: train loss 3.0006, val loss 2.9911
# step 4110: train loss 2.9535, val loss 3.0255
# step 4120: train loss 3.0359, val loss 3.0312
# step 4130: train loss 2.9603, val loss 2.9959
# step 4140: train loss 3.0641, val loss 3.1259
# step 4150: train loss 2.9974, val loss 2.9272
# step 4160: train loss 3.0161, val loss 3.0572
# step 4170: train loss 2.9608, val loss 2.9534
# step 4180: train loss 2.9230, val loss 3.1033
# step 4190: train loss 2.8484, val loss 2.9793
# step 4200: train loss 2.9420, val loss 2.9756
# step 4210: train loss 2.9774, val loss 2.9122
# step 4220: train loss 2.9860, val loss 3.0875
# step 4230: train loss 2.9368, val loss 2.9656
# step 4240: train loss 2.9674, val loss 2.9017
# step 4250: train loss 2.9686, val loss 3.0140
# step 4260: train loss 2.9595, val loss 2.9096
# step 4270: train loss 3.0336, val loss 3.1105
# step 4280: train loss 2.8204, val loss 3.0806
# step 4290: train loss 2.9359, val loss 3.1675
# step 4300: train loss 2.9680, val loss 2.9777
# step 4310: train loss 2.9132, val loss 3.0403
# step 4320: train loss 2.8621, val loss 3.0077
# step 4330: train loss 2.9235, val loss 3.0356
# step 4340: train loss 2.8120, val loss 3.1417
# step 4350: train loss 2.9718, val loss 2.9358
# step 4360: train loss 2.8928, val loss 2.9305
# step 4370: train loss 2.9536, val loss 2.9821
# step 4380: train loss 2.9375, val loss 3.0294
# step 4390: train loss 2.9459, val loss 2.9345
# step 4400: train loss 2.8898, val loss 2.9724
# step 4410: train loss 2.8488, val loss 2.9223
# step 4420: train loss 2.9890, val loss 2.9109
# step 4430: train loss 2.9433, val loss 2.8255
# step 4440: train loss 2.9519, val loss 3.0271
# step 4450: train loss 2.9292, val loss 2.9553
# step 4460: train loss 2.8443, val loss 2.8605
# step 4470: train loss 2.9601, val loss 2.9348
# step 4480: train loss 2.8368, val loss 2.9933
# step 4490: train loss 3.0021, val loss 2.9985
# step 4500: train loss 2.9303, val loss 2.8012
# step 4510: train loss 2.9049, val loss 2.8876
# step 4520: train loss 2.8855, val loss 2.9442
# step 4530: train loss 2.8632, val loss 2.9940
# step 4540: train loss 2.8968, val loss 2.9823
# step 4550: train loss 2.8382, val loss 2.9206
# step 4560: train loss 2.9600, val loss 2.9582
# step 4570: train loss 2.9168, val loss 3.0266
# step 4580: train loss 2.8936, val loss 2.9819
# step 4590: train loss 2.9296, val loss 2.9829
# step 4600: train loss 2.8683, val loss 2.9197
# step 4610: train loss 2.9352, val loss 2.8475
# step 4620: train loss 2.8819, val loss 2.9050
# step 4630: train loss 2.8241, val loss 2.8999
# step 4640: train loss 2.9241, val loss 2.8740
# step 4650: train loss 2.8607, val loss 2.8487
# step 4660: train loss 2.8554, val loss 3.0245
# step 4670: train loss 2.9328, val loss 2.9097
# step 4680: train loss 2.8710, val loss 2.9509
# step 4690: train loss 2.9015, val loss 2.8221
# step 4700: train loss 2.8533, val loss 3.0597
# step 4710: train loss 2.8884, val loss 2.9166
# step 4720: train loss 2.9523, val loss 2.9361
# step 4730: train loss 2.8615, val loss 2.8736
# step 4740: train loss 2.8827, val loss 2.8924
# step 4750: train loss 2.9347, val loss 2.9936
# step 4760: train loss 2.8876, val loss 2.8937
# step 4770: train loss 2.7918, val loss 2.9456
# step 4780: train loss 2.8576, val loss 2.9033
# step 4790: train loss 2.8468, val loss 2.9045
# step 4800: train loss 2.7874, val loss 2.9204
# step 4810: train loss 2.7811, val loss 2.7480
# step 4820: train loss 2.8548, val loss 2.8912
# step 4830: train loss 2.8725, val loss 2.8910
# step 4840: train loss 2.8423, val loss 2.8553
# step 4850: train loss 2.8389, val loss 2.9451
# step 4860: train loss 2.8432, val loss 2.8575
# step 4870: train loss 2.8627, val loss 2.8415
# step 4880: train loss 2.8939, val loss 2.9106
# step 4890: train loss 2.9361, val loss 2.9828
# step 4900: train loss 2.8101, val loss 2.8286
# step 4910: train loss 2.8178, val loss 2.8280
# step 4920: train loss 2.8940, val loss 2.7774
# step 4930: train loss 2.7479, val loss 2.9055
# step 4940: train loss 2.8467, val loss 2.9387
# step 4950: train loss 2.8067, val loss 2.8812
# step 4960: train loss 2.8870, val loss 2.9158
# step 4970: train loss 2.8280, val loss 2.7933
# step 4980: train loss 2.8732, val loss 2.8566
# step 4990: train loss 2.8166, val loss 2.8756
# step 5000: train loss 2.7775, val loss 2.8712
# step 5010: train loss 2.7943, val loss 2.7380
# step 5020: train loss 2.7799, val loss 2.8294
# step 5030: train loss 2.8166, val loss 2.8779
# step 5040: train loss 2.8447, val loss 2.8695
# step 5050: train loss 2.9030, val loss 2.8645
# step 5060: train loss 2.8148, val loss 2.8134
# step 5070: train loss 2.8375, val loss 2.8677
# step 5080: train loss 2.7900, val loss 2.8367
# step 5090: train loss 2.8815, val loss 2.7529
# step 5100: train loss 2.8467, val loss 2.7954
# step 5110: train loss 2.8022, val loss 2.8721
# step 5120: train loss 2.8033, val loss 2.8298
# step 5130: train loss 2.7687, val loss 3.0216
# step 5140: train loss 2.8501, val loss 2.9621
# step 5150: train loss 2.7550, val loss 2.8013
# step 5160: train loss 2.7584, val loss 2.8301
# step 5170: train loss 2.7962, val loss 2.9731
# step 5180: train loss 2.8860, val loss 2.9301
# step 5190: train loss 2.8027, val loss 2.9178
# step 5200: train loss 2.7896, val loss 2.9315
# step 5210: train loss 2.8297, val loss 2.8387
# step 5220: train loss 2.7848, val loss 2.9315
# step 5230: train loss 2.7373, val loss 2.7978
# step 5240: train loss 2.7977, val loss 2.7946
# step 5250: train loss 2.7578, val loss 2.7975
# step 5260: train loss 2.7628, val loss 2.8234
# step 5270: train loss 2.7396, val loss 2.8103
# step 5280: train loss 2.7810, val loss 2.9603
# step 5290: train loss 2.7713, val loss 2.8242
# step 5300: train loss 2.7310, val loss 2.8519
# step 5310: train loss 2.8459, val loss 2.8791
# step 5320: train loss 2.7519, val loss 2.8187
# step 5330: train loss 2.7883, val loss 2.7814
# step 5340: train loss 2.7982, val loss 2.9085
# step 5350: train loss 2.7304, val loss 2.8294
# step 5360: train loss 2.6844, val loss 2.8424
# step 5370: train loss 2.8116, val loss 2.8372
# step 5380: train loss 2.7555, val loss 2.8955
# step 5390: train loss 2.7740, val loss 2.7685
# step 5400: train loss 2.7505, val loss 2.7367
# step 5410: train loss 2.7492, val loss 2.7914
# step 5420: train loss 2.7330, val loss 2.8172
# step 5430: train loss 2.8279, val loss 2.8188
# step 5440: train loss 2.7518, val loss 2.7478
# step 5450: train loss 2.7853, val loss 2.7395
# step 5460: train loss 2.7653, val loss 2.7605
# step 5470: train loss 2.7617, val loss 2.8299
# step 5480: train loss 2.8046, val loss 2.8044
# step 5490: train loss 2.7493, val loss 2.7298
# step 5500: train loss 2.7599, val loss 2.8022
# step 5510: train loss 2.7024, val loss 2.7602
# step 5520: train loss 2.7589, val loss 2.8518
# step 5530: train loss 2.7655, val loss 2.7759
# step 5540: train loss 2.7972, val loss 2.8420
# step 5550: train loss 2.6336, val loss 2.7611
# step 5560: train loss 2.7558, val loss 2.8031
# step 5570: train loss 2.8045, val loss 2.8566
# step 5580: train loss 2.8065, val loss 2.8884
# step 5590: train loss 2.8017, val loss 2.7743
# step 5600: train loss 2.7718, val loss 2.8040
# step 5610: train loss 2.7335, val loss 2.7876
# step 5620: train loss 2.7740, val loss 2.8176
# step 5630: train loss 2.7401, val loss 2.7929
# step 5640: train loss 2.6924, val loss 2.8632
# step 5650: train loss 2.6244, val loss 2.7733
# step 5660: train loss 2.7010, val loss 2.6867
# step 5670: train loss 2.7046, val loss 2.7308
# step 5680: train loss 2.6965, val loss 2.7999
# step 5690: train loss 2.7166, val loss 2.7817
# step 5700: train loss 2.7606, val loss 2.6968
# step 5710: train loss 2.7092, val loss 2.7084
# step 5720: train loss 2.7692, val loss 2.8515
# step 5730: train loss 2.6769, val loss 2.8126
# step 5740: train loss 2.8536, val loss 2.7939
# step 5750: train loss 2.7749, val loss 2.7449
# step 5760: train loss 2.7097, val loss 2.7756
# step 5770: train loss 2.7413, val loss 2.7543
# step 5780: train loss 2.5839, val loss 2.7562
# step 5790: train loss 2.7698, val loss 2.8038
# step 5800: train loss 2.6876, val loss 2.6716
# step 5810: train loss 2.7285, val loss 2.7931
# step 5820: train loss 2.7530, val loss 2.8132
# step 5830: train loss 2.7859, val loss 2.7959
# step 5840: train loss 2.7285, val loss 2.7151
# step 5850: train loss 2.7416, val loss 2.8379
# step 5860: train loss 2.7375, val loss 2.7433
# step 5870: train loss 2.7281, val loss 2.8334
# step 5880: train loss 2.7810, val loss 2.7247
# step 5890: train loss 2.7433, val loss 2.7097
# step 5900: train loss 2.7347, val loss 2.8562
# step 5910: train loss 2.7679, val loss 2.7858
# step 5920: train loss 2.7347, val loss 2.7833
# step 5930: train loss 2.7558, val loss 2.7856
# step 5940: train loss 2.7072, val loss 2.8228
# step 5950: train loss 2.6626, val loss 2.7190
# step 5960: train loss 2.7497, val loss 2.7188
# step 5970: train loss 2.7620, val loss 2.6708
# step 5980: train loss 2.7385, val loss 2.8386
# step 5990: train loss 2.7218, val loss 2.8834
# step 6000: train loss 2.7165, val loss 2.7626
# step 6010: train loss 2.7227, val loss 2.7495
# step 6020: train loss 2.7356, val loss 2.7571
# step 6030: train loss 2.6196, val loss 2.7546
# step 6040: train loss 2.8070, val loss 2.8030
# step 6050: train loss 2.7530, val loss 2.8002
# step 6060: train loss 2.7013, val loss 2.8588
# step 6070: train loss 2.6684, val loss 2.7026
# step 6080: train loss 2.7157, val loss 2.8313
# step 6090: train loss 2.7133, val loss 2.9046
# step 6100: train loss 2.7243, val loss 2.8280
# step 6110: train loss 2.7393, val loss 2.7694
# step 6120: train loss 2.7283, val loss 2.8007
# step 6130: train loss 2.7643, val loss 2.8247
# step 6140: train loss 2.7479, val loss 2.8198
# step 6150: train loss 2.6949, val loss 2.6727
# step 6160: train loss 2.6598, val loss 2.8558
# step 6170: train loss 2.6327, val loss 2.6280
# step 6180: train loss 2.6297, val loss 2.6977
# step 6190: train loss 2.7110, val loss 2.6811
# step 6200: train loss 2.7164, val loss 2.6798
# step 6210: train loss 2.6077, val loss 2.6970
# step 6220: train loss 2.6458, val loss 2.6512
# step 6230: train loss 2.6965, val loss 2.7003
# step 6240: train loss 2.6676, val loss 2.7422
# step 6250: train loss 2.6680, val loss 2.6813
# step 6260: train loss 2.6900, val loss 2.6652
# step 6270: train loss 2.6118, val loss 2.7675
# step 6280: train loss 2.5918, val loss 2.6510
# step 6290: train loss 2.6650, val loss 2.6979
# step 6300: train loss 2.6468, val loss 2.6793
# step 6310: train loss 2.5822, val loss 2.7846
# step 6320: train loss 2.7439, val loss 2.7119
# step 6330: train loss 2.6118, val loss 2.7714
# step 6340: train loss 2.7446, val loss 2.6659
# step 6350: train loss 2.6959, val loss 2.7782
# step 6360: train loss 2.6481, val loss 2.8114
# step 6370: train loss 2.6384, val loss 2.8244
# step 6380: train loss 2.6947, val loss 2.7488
# step 6390: train loss 2.6283, val loss 2.6734
# step 6400: train loss 2.6185, val loss 2.7282
# step 6410: train loss 2.6722, val loss 2.7322
# step 6420: train loss 2.6911, val loss 2.6511
# step 6430: train loss 2.7511, val loss 2.6567
# step 6440: train loss 2.6686, val loss 2.6951
# step 6450: train loss 2.7386, val loss 2.7837
# step 6460: train loss 2.6728, val loss 2.7611
# step 6470: train loss 2.6914, val loss 2.7840
# step 6480: train loss 2.6946, val loss 2.7282
# step 6490: train loss 2.5652, val loss 2.8010
# step 6500: train loss 2.6657, val loss 2.6664
# step 6510: train loss 2.5708, val loss 2.7083
# step 6520: train loss 2.7072, val loss 2.7878
# step 6530: train loss 2.6147, val loss 2.7097
# step 6540: train loss 2.6519, val loss 2.7132
# step 6550: train loss 2.6200, val loss 2.6470
# step 6560: train loss 2.6306, val loss 2.7197
# step 6570: train loss 2.7135, val loss 2.7906
# step 6580: train loss 2.6905, val loss 2.7089
# step 6590: train loss 2.6601, val loss 2.6888
# step 6600: train loss 2.6071, val loss 2.7873
# step 6610: train loss 2.7192, val loss 2.6841
# step 6620: train loss 2.7781, val loss 2.7107
# step 6630: train loss 2.6621, val loss 2.5936
# step 6640: train loss 2.6586, val loss 2.8111
# step 6650: train loss 2.6550, val loss 2.7265
# step 6660: train loss 2.6164, val loss 2.7625
# step 6670: train loss 2.6867, val loss 2.7018
# step 6680: train loss 2.6348, val loss 2.6757
# step 6690: train loss 2.6081, val loss 2.8388
# step 6700: train loss 2.5684, val loss 2.8376
# step 6710: train loss 2.6299, val loss 2.7454
# step 6720: train loss 2.6312, val loss 2.5724
# step 6730: train loss 2.6350, val loss 2.6955
# step 6740: train loss 2.6384, val loss 2.7096
# step 6750: train loss 2.6138, val loss 2.6821
# step 6760: train loss 2.5548, val loss 2.6441
# step 6770: train loss 2.6275, val loss 2.6369
# step 6780: train loss 2.6801, val loss 2.7666
# step 6790: train loss 2.6529, val loss 2.6458
# step 6800: train loss 2.6931, val loss 2.6765
# step 6810: train loss 2.6174, val loss 2.7671
# step 6820: train loss 2.6255, val loss 2.7860
# step 6830: train loss 2.6256, val loss 2.7231
# step 6840: train loss 2.6228, val loss 2.6361
# step 6850: train loss 2.6662, val loss 2.7788
# step 6860: train loss 2.6567, val loss 2.7543
# step 6870: train loss 2.6278, val loss 2.7143
# step 6880: train loss 2.5644, val loss 2.6460
# step 6890: train loss 2.6759, val loss 2.7221
# step 6900: train loss 2.7117, val loss 2.5687
# step 6910: train loss 2.6666, val loss 2.7541
# step 6920: train loss 2.6093, val loss 2.6836
# step 6930: train loss 2.5992, val loss 2.6773
# step 6940: train loss 2.6447, val loss 2.7412
# step 6950: train loss 2.6805, val loss 2.7273
# step 6960: train loss 2.6207, val loss 2.6393
# step 6970: train loss 2.6078, val loss 2.7091
# step 6980: train loss 2.6547, val loss 2.6026
# step 6990: train loss 2.6735, val loss 2.7915
# step 7000: train loss 2.6526, val loss 2.7518
# step 7010: train loss 2.6589, val loss 2.6741
# step 7020: train loss 2.6346, val loss 2.6287
# step 7030: train loss 2.6529, val loss 2.7268
# step 7040: train loss 2.5158, val loss 2.6396
# step 7050: train loss 2.6478, val loss 2.6570
# step 7060: train loss 2.7151, val loss 2.7566
# step 7070: train loss 2.6082, val loss 2.6260
# step 7080: train loss 2.5592, val loss 2.6626
# step 7090: train loss 2.5984, val loss 2.7168
# step 7100: train loss 2.6391, val loss 2.8091
# step 7110: train loss 2.5417, val loss 2.6411
# step 7120: train loss 2.6098, val loss 2.7398
# step 7130: train loss 2.5816, val loss 2.6819
# step 7140: train loss 2.6028, val loss 2.7043
# step 7150: train loss 2.6060, val loss 2.6223
# step 7160: train loss 2.5179, val loss 2.5578
# step 7170: train loss 2.6018, val loss 2.8099
# step 7180: train loss 2.6706, val loss 2.6119
# step 7190: train loss 2.6785, val loss 2.7574
# step 7200: train loss 2.6162, val loss 2.6735
# step 7210: train loss 2.5832, val loss 2.6507
# step 7220: train loss 2.5649, val loss 2.6783
# step 7230: train loss 2.6105, val loss 2.6065
# step 7240: train loss 2.6392, val loss 2.7251
# step 7250: train loss 2.6036, val loss 2.6761
# step 7260: train loss 2.6186, val loss 2.6864
# step 7270: train loss 2.6264, val loss 2.6216
# step 7280: train loss 2.6403, val loss 2.5867
# step 7290: train loss 2.6414, val loss 2.8060
# step 7300: train loss 2.5811, val loss 2.6215
# step 7310: train loss 2.6548, val loss 2.7151
# step 7320: train loss 2.5786, val loss 2.8482
# step 7330: train loss 2.5307, val loss 2.6544
# step 7340: train loss 2.5956, val loss 2.7014
# step 7350: train loss 2.5624, val loss 2.7214
# step 7360: train loss 2.5818, val loss 2.7714
# step 7370: train loss 2.5250, val loss 2.7065
# step 7380: train loss 2.5867, val loss 2.6812
# step 7390: train loss 2.5807, val loss 2.6654
# step 7400: train loss 2.5727, val loss 2.6889
# step 7410: train loss 2.5918, val loss 2.6447
# step 7420: train loss 2.5999, val loss 2.7607
# step 7430: train loss 2.6778, val loss 2.6674
# step 7440: train loss 2.6696, val loss 2.6174
# step 7450: train loss 2.6660, val loss 2.6789
# step 7460: train loss 2.5348, val loss 2.6882
# step 7470: train loss 2.5169, val loss 2.6701
# step 7480: train loss 2.5927, val loss 2.6327
# step 7490: train loss 2.4807, val loss 2.5949
# step 7500: train loss 2.5888, val loss 2.7000
# step 7510: train loss 2.6172, val loss 2.7044
# step 7520: train loss 2.5945, val loss 2.7202
# step 7530: train loss 2.5939, val loss 2.7263
# step 7540: train loss 2.5943, val loss 2.6232
# step 7550: train loss 2.5280, val loss 2.5608
# step 7560: train loss 2.6310, val loss 2.5921
# step 7570: train loss 2.6153, val loss 2.6037
# step 7580: train loss 2.5206, val loss 2.7239
# step 7590: train loss 2.5851, val loss 2.5742
# step 7600: train loss 2.6802, val loss 2.6784
# step 7610: train loss 2.6231, val loss 2.5684
# step 7620: train loss 2.5893, val loss 2.7811
# step 7630: train loss 2.5415, val loss 2.6866
# step 7640: train loss 2.6042, val loss 2.6264
# step 7650: train loss 2.5868, val loss 2.6268
# step 7660: train loss 2.6319, val loss 2.5731
# step 7670: train loss 2.5563, val loss 2.7176
# step 7680: train loss 2.6163, val loss 2.6472
# step 7690: train loss 2.5815, val loss 2.6817
# step 7700: train loss 2.6235, val loss 2.5465
# step 7710: train loss 2.5224, val loss 2.5755
# step 7720: train loss 2.6337, val loss 2.5280
# step 7730: train loss 2.5691, val loss 2.5703
# step 7740: train loss 2.5244, val loss 2.6825
# step 7750: train loss 2.6109, val loss 2.7841
# step 7760: train loss 2.5075, val loss 2.6651
# step 7770: train loss 2.6001, val loss 2.6624
# step 7780: train loss 2.5558, val loss 2.6019
# step 7790: train loss 2.5843, val loss 2.6715
# step 7800: train loss 2.5510, val loss 2.5982
# step 7810: train loss 2.6618, val loss 2.7273
# step 7820: train loss 2.5408, val loss 2.7059
# step 7830: train loss 2.6600, val loss 2.5128
# step 7840: train loss 2.6082, val loss 2.5672
# step 7850: train loss 2.5354, val loss 2.5799
# step 7860: train loss 2.5894, val loss 2.6927
# step 7870: train loss 2.6896, val loss 2.7159
# step 7880: train loss 2.6105, val loss 2.6574
# step 7890: train loss 2.5514, val loss 2.5623
# step 7900: train loss 2.6357, val loss 2.5640
# step 7910: train loss 2.5259, val loss 2.5933
# step 7920: train loss 2.6075, val loss 2.6814
# step 7930: train loss 2.6012, val loss 2.6379
# step 7940: train loss 2.5638, val loss 2.5806
# step 7950: train loss 2.6210, val loss 2.6400
# step 7960: train loss 2.6066, val loss 2.7279
# step 7970: train loss 2.5419, val loss 2.7601
# step 7980: train loss 2.5784, val loss 2.6192
# step 7990: train loss 2.5081, val loss 2.5955
# step 8000: train loss 2.5586, val loss 2.6168
# step 8010: train loss 2.5728, val loss 2.6064
# step 8020: train loss 2.5243, val loss 2.6139
# step 8030: train loss 2.5400, val loss 2.6203
# step 8040: train loss 2.5937, val loss 2.5071
# step 8050: train loss 2.5886, val loss 2.7087
# step 8060: train loss 2.5113, val loss 2.5810
# step 8070: train loss 2.6219, val loss 2.6562
# step 8080: train loss 2.5510, val loss 2.6169
# step 8090: train loss 2.5556, val loss 2.5588
# step 8100: train loss 2.5758, val loss 2.6224
# step 8110: train loss 2.5209, val loss 2.6598
# step 8120: train loss 2.5960, val loss 2.6325
# step 8130: train loss 2.5528, val loss 2.5638
# step 8140: train loss 2.5031, val loss 2.5994
# step 8150: train loss 2.5314, val loss 2.5488
# step 8160: train loss 2.5858, val loss 2.6256
# step 8170: train loss 2.5842, val loss 2.6713
# step 8180: train loss 2.6104, val loss 2.6838
# step 8190: train loss 2.5690, val loss 2.6115
# step 8200: train loss 2.5849, val loss 2.7180
# step 8210: train loss 2.6559, val loss 2.5322
# step 8220: train loss 2.5947, val loss 2.5475
# step 8230: train loss 2.5631, val loss 2.6461
# step 8240: train loss 2.6028, val loss 2.5031
# step 8250: train loss 2.5868, val loss 2.5735
# step 8260: train loss 2.4612, val loss 2.6373
# step 8270: train loss 2.6252, val loss 2.6447
# step 8280: train loss 2.5504, val loss 2.6064
# step 8290: train loss 2.6059, val loss 2.6135
# step 8300: train loss 2.6064, val loss 2.7005
# step 8310: train loss 2.5683, val loss 2.6567
# step 8320: train loss 2.5818, val loss 2.6243
# step 8330: train loss 2.5707, val loss 2.6373
# step 8340: train loss 2.5445, val loss 2.7263
# step 8350: train loss 2.6263, val loss 2.5951
# step 8360: train loss 2.5183, val loss 2.6369
# step 8370: train loss 2.6000, val loss 2.6309
# step 8380: train loss 2.5268, val loss 2.6827
# step 8390: train loss 2.5340, val loss 2.6892
# step 8400: train loss 2.4833, val loss 2.6012
# step 8410: train loss 2.5075, val loss 2.5595
# step 8420: train loss 2.5167, val loss 2.7023
# step 8430: train loss 2.5592, val loss 2.6228
# step 8440: train loss 2.5140, val loss 2.6134
# step 8450: train loss 2.5315, val loss 2.5237
# step 8460: train loss 2.4647, val loss 2.6315
# step 8470: train loss 2.6019, val loss 2.6740
# step 8480: train loss 2.5515, val loss 2.6235
# step 8490: train loss 2.4695, val loss 2.6425
# step 8500: train loss 2.5341, val loss 2.6676
# step 8510: train loss 2.5496, val loss 2.6488
# step 8520: train loss 2.5338, val loss 2.5619
# step 8530: train loss 2.5581, val loss 2.6530
# step 8540: train loss 2.5446, val loss 2.4530
# step 8550: train loss 2.5099, val loss 2.5609
# step 8560: train loss 2.5931, val loss 2.5289
# step 8570: train loss 2.5663, val loss 2.6262
# step 8580: train loss 2.5666, val loss 2.5944
# step 8590: train loss 2.5382, val loss 2.7177
# step 8600: train loss 2.5519, val loss 2.6106
# step 8610: train loss 2.4914, val loss 2.5753
# step 8620: train loss 2.5916, val loss 2.6543
# step 8630: train loss 2.5629, val loss 2.6849
# step 8640: train loss 2.5082, val loss 2.5268
# step 8650: train loss 2.5771, val loss 2.5924
# step 8660: train loss 2.5099, val loss 2.6083
# step 8670: train loss 2.5454, val loss 2.6202
# step 8680: train loss 2.5484, val loss 2.5018
# step 8690: train loss 2.5555, val loss 2.6358
# step 8700: train loss 2.4647, val loss 2.5836
# step 8710: train loss 2.5082, val loss 2.4954
# step 8720: train loss 2.5639, val loss 2.5573
# step 8730: train loss 2.5292, val loss 2.6155
# step 8740: train loss 2.5731, val loss 2.5945
# step 8750: train loss 2.6166, val loss 2.6890
# step 8760: train loss 2.4838, val loss 2.6007
# step 8770: train loss 2.5800, val loss 2.5622
# step 8780: train loss 2.5337, val loss 2.5789
# step 8790: train loss 2.5571, val loss 2.7290
# step 8800: train loss 2.5063, val loss 2.6036
# step 8810: train loss 2.4949, val loss 2.6281
# step 8820: train loss 2.5307, val loss 2.5262
# step 8830: train loss 2.5239, val loss 2.5731
# step 8840: train loss 2.5148, val loss 2.6327
# step 8850: train loss 2.5545, val loss 2.6448
# step 8860: train loss 2.4888, val loss 2.5533
# step 8870: train loss 2.4984, val loss 2.6429
# step 8880: train loss 2.5726, val loss 2.5968
# step 8890: train loss 2.4809, val loss 2.5269
# step 8900: train loss 2.4974, val loss 2.6989
# step 8910: train loss 2.4623, val loss 2.6846
# step 8920: train loss 2.5877, val loss 2.6295
# step 8930: train loss 2.5681, val loss 2.7359
# step 8940: train loss 2.5158, val loss 2.5929
# step 8950: train loss 2.4600, val loss 2.5715
# step 8960: train loss 2.5554, val loss 2.5646
# step 8970: train loss 2.5570, val loss 2.6297
# step 8980: train loss 2.5352, val loss 2.6049
# step 8990: train loss 2.5066, val loss 2.6174
# step 9000: train loss 2.4740, val loss 2.4496
# step 9010: train loss 2.5061, val loss 2.6196
# step 9020: train loss 2.4550, val loss 2.5375
# step 9030: train loss 2.5253, val loss 2.6431
# step 9040: train loss 2.4565, val loss 2.5373
# step 9050: train loss 2.5080, val loss 2.5612
# step 9060: train loss 2.5852, val loss 2.6362
# step 9070: train loss 2.5543, val loss 2.5508
# step 9080: train loss 2.5064, val loss 2.5054
# step 9090: train loss 2.4765, val loss 2.7078
# step 9100: train loss 2.6344, val loss 2.6374
# step 9110: train loss 2.5175, val loss 2.6179
# step 9120: train loss 2.5271, val loss 2.5820
# step 9130: train loss 2.5347, val loss 2.6061
# step 9140: train loss 2.5521, val loss 2.6860
# step 9150: train loss 2.5696, val loss 2.5556
# step 9160: train loss 2.5188, val loss 2.5732
# step 9170: train loss 2.4857, val loss 2.6116
# step 9180: train loss 2.5875, val loss 2.6138
# step 9190: train loss 2.5612, val loss 2.6414
# step 9200: train loss 2.5010, val loss 2.4496
# step 9210: train loss 2.4709, val loss 2.6548
# step 9220: train loss 2.4473, val loss 2.5187
# step 9230: train loss 2.4885, val loss 2.5466
# step 9240: train loss 2.5144, val loss 2.5949
# step 9250: train loss 2.4905, val loss 2.6349
# step 9260: train loss 2.5048, val loss 2.6445
# step 9270: train loss 2.5653, val loss 2.6379
# step 9280: train loss 2.5277, val loss 2.5073
# step 9290: train loss 2.4884, val loss 2.4981
# step 9300: train loss 2.5143, val loss 2.5431
# step 9310: train loss 2.5172, val loss 2.5188
# step 9320: train loss 2.5640, val loss 2.5901
# step 9330: train loss 2.4894, val loss 2.5739
# step 9340: train loss 2.4196, val loss 2.6816
# step 9350: train loss 2.4998, val loss 2.6372
# step 9360: train loss 2.4574, val loss 2.5696
# step 9370: train loss 2.5300, val loss 2.6413
# step 9380: train loss 2.6294, val loss 2.5446
# step 9390: train loss 2.5413, val loss 2.5911
# step 9400: train loss 2.5024, val loss 2.5749
# step 9410: train loss 2.4380, val loss 2.5177
# step 9420: train loss 2.4882, val loss 2.5266
# step 9430: train loss 2.5630, val loss 2.6080
# step 9440: train loss 2.5749, val loss 2.5655
# step 9450: train loss 2.5811, val loss 2.5924
# step 9460: train loss 2.5737, val loss 2.5867
# step 9470: train loss 2.5490, val loss 2.5730
# step 9480: train loss 2.4861, val loss 2.5288
# step 9490: train loss 2.5477, val loss 2.6197
# step 9500: train loss 2.5197, val loss 2.6518
# step 9510: train loss 2.5056, val loss 2.5610
# step 9520: train loss 2.5457, val loss 2.6267
# step 9530: train loss 2.5138, val loss 2.5666
# step 9540: train loss 2.4558, val loss 2.5489
# step 9550: train loss 2.5155, val loss 2.5617
# step 9560: train loss 2.5961, val loss 2.5698
# step 9570: train loss 2.5299, val loss 2.5902
# step 9580: train loss 2.4713, val loss 2.6092
# step 9590: train loss 2.5142, val loss 2.5891
# step 9600: train loss 2.5727, val loss 2.6397
# step 9610: train loss 2.4995, val loss 2.5816
# step 9620: train loss 2.5381, val loss 2.5687
# step 9630: train loss 2.4454, val loss 2.4940
# step 9640: train loss 2.4452, val loss 2.4633
# step 9650: train loss 2.5344, val loss 2.6026
# step 9660: train loss 2.5012, val loss 2.4964
# step 9670: train loss 2.4589, val loss 2.5638
# step 9680: train loss 2.4804, val loss 2.6379
# step 9690: train loss 2.3998, val loss 2.5906
# step 9700: train loss 2.4671, val loss 2.5764
# step 9710: train loss 2.4901, val loss 2.6384
# step 9720: train loss 2.5058, val loss 2.7695
# step 9730: train loss 2.5860, val loss 2.5614
# step 9740: train loss 2.4588, val loss 2.7513
# step 9750: train loss 2.4835, val loss 2.5850
# step 9760: train loss 2.5283, val loss 2.5137
# step 9770: train loss 2.5399, val loss 2.5453
# step 9780: train loss 2.6068, val loss 2.5512
# step 9790: train loss 2.5088, val loss 2.5590
# step 9800: train loss 2.5664, val loss 2.5138
# step 9810: train loss 2.5489, val loss 2.6148
# step 9820: train loss 2.4831, val loss 2.5326
# step 9830: train loss 2.4931, val loss 2.6346
# step 9840: train loss 2.4945, val loss 2.5834
# step 9850: train loss 2.4559, val loss 2.6091
# step 9860: train loss 2.5234, val loss 2.5305
# step 9870: train loss 2.5041, val loss 2.5740
# step 9880: train loss 2.4345, val loss 2.5356
# step 9890: train loss 2.5409, val loss 2.5642
# step 9900: train loss 2.4612, val loss 2.4161
# step 9910: train loss 2.4493, val loss 2.4965
# step 9920: train loss 2.5756, val loss 2.4500
# step 9930: train loss 2.5191, val loss 2.6127
# step 9940: train loss 2.4268, val loss 2.5915
# step 9950: train loss 2.5578, val loss 2.5987
# step 9960: train loss 2.5335, val loss 2.5839
# step 9970: train loss 2.5275, val loss 2.5205
# step 9980: train loss 2.5302, val loss 2.6239
# step 9990: train loss 2.4097, val loss 2.5951

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# Qôntont duspon llaimJ4Éme afNyes  c  es;É!V(qu
# P3épobasoc'âmis vor deu es mages  nges qutet u arf d«

# %% [markdown]
# Résultats pour :
# - 100 itérations:
#     - step 90: train loss 5.1004, val loss 5.1654
#     - Phrase générée :  ëËHtÎTmgÎQrzNsî2lUUê
#                         Î;çbïÂ«ZM-KVË75ÎSHùIJKnlÎlE
#                         O1CNe:4ïm.ÆK'  vrAMÎCeû3Ô!uÊ[VsïË!5Ad2çBfljVÔ-oUsJn
#
# - 1 000 itérations :
#     - step 990: train loss 4.3470, val loss 4.4109
#     - Phrase générée :  TâP6hTwN88R
#                         X; :pôZç08ùùDÔ mgi,!uË;Lbx2zw·îDîE.ç
#                         O»qyAq4À.PÊ«SÈô?àIE3«4[WkDDaAmr.-Jb5krhÔÀûetù,ÈvÈë_
# - 10 000 itérations :
#     - step 9990: train loss 2.4097, val loss 2.5951
#     - Phrase générée : Qôntont duspon llaimJ4Éme afNyes  c  es;É!V(qu
#                         P3épobasoc'âmis vor deu es mages  nges qutet u arf d«

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %%
print("Les deux matrices sont identiques : ", torch.equal(weights0, weights))
# Out:
# Les deux matrices sont identiques :  True

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)

# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value = nn.Linear(C, head_size)

# apply each layer to the input
k = key(x) # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)

# compute the normalize product between Q and K 
weights = q @ k.transpose(-2, -1) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)

# apply the normalization factor
weights = weights / (head_size ** 0.5) 

# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))

# apply the softmax
weights = F.softmax(weights, dim=-1) 

###
out  = weights @ v # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[-0.6798, -0.4775,  0.2736,  0.0887, -0.7935,  0.4090,  1.1175,  0.1106,
#           0.3843, -0.5742,  0.4032, -0.8593,  0.4649, -0.1426, -0.3598,  0.3221],
#         [-0.1445, -0.4160, -0.6584,  0.3551, -0.2450, -0.0633,  0.4067,  0.2841,
#           0.3354,  0.0861, -0.1445,  0.4309,  0.1878,  0.0767, -0.4898,  0.4585],
#         [ 0.1194, -0.2802, -0.4728,  0.1983, -0.2940,  0.1481,  0.1735,  0.2097,
#          -0.0522,  0.2932, -0.2271,  0.4514,  0.0796,  0.1870, -0.6333,  0.2579],
#         [-0.1066, -0.0808, -0.1325, -0.1787, -0.3585, -0.0016,  0.5329, -0.0277,
#          -0.0447, -0.2252,  0.2014,  0.0713,  0.1439,  0.1834, -0.4007,  0.1321],
#         [-0.0486, -0.0596, -0.4271, -0.0085, -0.2433,  0.1287, -0.0911,  0.0188,
#          -0.0396,  0.3536,  0.2995,  0.5636, -0.1961,  0.2727, -0.5388,  0.0785],
#         [-0.2495,  0.2067,  0.1921, -0.2970, -0.5214,  0.4651,  0.0446, -0.0151,
#          -0.3112,  0.2319,  0.4428,  0.0189, -0.1169,  0.2036, -0.5513, -0.1851],
#         [-0.1690,  0.1159, -0.0637, -0.2400, -0.4451,  0.1742,  0.3085,  0.0129,
#          -0.0881,  0.0251,  0.3498,  0.3081,  0.0575,  0.3286, -0.3821, -0.1304],
#         [-0.2628,  0.0177,  0.0133, -0.2677, -0.3089,  0.2366,  0.1861,  0.0485,
#          -0.0841,  0.3279,  0.2554,  0.1373,  0.0750,  0.2018, -0.4804, -0.2183]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# 0.009989 M parameters
# step 4999: train loss 2.3340, val loss 2.4363
#
# File "/home/onyxia/work/nlp-lab-language-models/gpt_single_head.py", line 102, in forward
#     out = weights @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
#           ~~~~~~~~^~~
# RuntimeError: Expected size for first two dimensions of batch2 tensor to be: [1, 8] but got: [1, 1].

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results
        heads = [h(x) for h in self.heads]
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %% [markdown]
# A faire !

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
